# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d
p = [200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1500,1600, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 7000,9000, 10000]
lp = [2.84,2.8,2.8,2.8,2.8,2.76,2.76,2.72,2.68,2.64,2.64,2.64,2.6,2.6,2.36,2.16,1.96,1.72,1.52,1.32,1.16,1,0.88,0.68,0.44,0.4]
bp = [0.48,0.66,0.82,0.84,1.12,1.44,1.68,1.92,2.08,2.2,2.44,2.64,2.96,3.08,3.56,4.08,4.12,4.16,4.16,4.12,3.96,3.8,3.44,2.84,2.64,2.6]
hp = [0.024,0.04,0.056,0.072,0.108,0.12,0.152,0.184,0.228,0.264,0.312,0.36,0.464,0.528,0.76,1.08,1.4,1.64,1.82,2,2.14,2.28,2.36,2.52,2.64,2.72]
num = 2.04
res = []
for val in lp:
    res.append(val/num)
res1 = []
for val in bp:
    res1.append(val/num)
res2 = []
for val in hp:
    res2.append(val/num)
plt.plot(p,res,'o--')
plt.plot(p,res1,'o--')
plt.plot(p,res2,'o--')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Vout/Vin')
plt.legend(['lp','bp','hp'])
plt.title('Plot of Transfer function vs Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d
p = [200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1500,1600, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 7000,9000, 10000]
lp = [2.84,2.8,2.8,2.8,2.8,2.76,2.76,2.72,2.68,2.64,2.64,2.64,2.6,2.6,2.36,2.16,1.96,1.72,1.52,1.32,1.16,1,0.88,0.68,0.44,0.4]
bp = [0.48,0.66,0.82,0.84,1.12,1.44,1.68,1.92,2.08,2.2,2.44,2.64,2.96,3.08,3.56,4.08,4.12,4.16,4.16,4.12,3.96,3.8,3.44,2.84,2.64,2.6]
hp = [0.024,0.04,0.056,0.072,0.108,0.12,0.152,0.184,0.228,0.264,0.312,0.36,0.464,0.528,0.76,1.08,1.4,1.64,1.82,2,2.14,2.28,2.36,2.52,2.64,2.72]
num = 2.04
res = []
for val in lp:
    res.append(20*math.log((val/num),10))
res1 = []
for val in bp:
    res1.append(20*math.log((val/num),10))
res2 = []
for val in hp:
    res2.append(20*math.log((val/num),10))
plt.plot(p,res,'o--')
plt.plot(p,res1,'o--')
plt.plot(p,res2,'o--')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Vout/Vin')
plt.title('Bode Plot of Transfer function vs Frequency')
plt.legend(['lp','bp','hp'])
plt.show()
